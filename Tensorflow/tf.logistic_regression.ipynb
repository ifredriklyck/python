# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import time
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

iris = load_iris()
iris_X, iris_y = iris.data[:-1,:], iris.target[:-1]
iris_y= pd.get_dummies(iris_y).values
trainX, testX, trainY, testY = train_test_split(iris_X, iris_y, test_size=0.33, random_state=42)

# numFeatures is the number of features in our input data.
# In the iris dataset, this number is '4'.
numFeatures = trainX.shape[1]

# numLabels is the number of classes our data points can be in.
# In the iris dataset, this number is'3'.
numLabels = trainY.shape[1]

# Placeholders
# 'None' means Tensorflow shouldn't expect a fixed number in that dimension
X = tf.placeholder(tf.float32, [None, numFeatures]) # Iris has 4 features, so X is a tensor to hold our data.
yGold = tf.placeholder(tf.float32, [None, numLabels]) # This will be our correct answers matrix for 3 classes.

W = tf.Variable(tf.zeros([4, 3])) # 4-dimensional input and 3 classes
b = tf.Variable(tf.zeros([3])) # 3-dimensional output [0,0,1],[0,1,0],[1,0,0]

# Randomly sample from a normal distribution with standard deviation .01

weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                      mean=0,
                                      stddev=0.01,
                                      name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                   mean=0,
                                   stddev=0.01,
                                   name="bias"))

# Three-component breakdown of the Logistic Regression function.
# Note that these feed into each other.
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias")
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# Number of Epochs in our training
numEpochs = 700

# Defining our learning rate iterations (decay)
learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                         global_step= 1,
                                         decay_steps=trainX.shape[0],
                                         decay_rate= 0.95,
                                         staircase=True)

# Defining our cost function - Squared Mean Error
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

# Defininf our Gradient Descent
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# Create a Tensorflow session
sess = tf.Session()

# Initialize our weights and biases variables
init_OP = tf.global_variables_initializer()

# Initialize all Tensorflow variables
sess.run(init_OP)

# argmax(activation_OP, 1) returns the label with the most probablity
# argmax(yGold, 1) is the correct label
correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))

# If every false prediction is 0 and every true prediction is 1, the average returns us the accuracy
accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))

# Summary op for regression output
activation_summary_OP = tf.summary.histogram("output", activation_OP)

# Summary op for accuracy
accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)

# Summary op for cost
cost_summary_OP = tf.summary.scalar("cost", cost_OP)

# Summary ops to check how variables(W, b) are updating after each iteration
weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))

# Merge all summaries
merged = tf.summary.merge([activation_summary_OP, accuracy_summary_OP, cost_summary_OP, weightSummary, biasSummary])

# Summary writer
writer = tf.summary.FileWriter("summary_logs", sess.graph)

# Initialize reporting variables
cost = 0
diff = 1
epoch_values = []
accuracy_values = []
cost_values = []

# Training epochs
for i in range(numEpochs):
    if i > 1 and diff < .0001:
        print("change in cost %g; convergence."%diff)
        break
    else:
        # Run training step
        step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
        # Report occasional stats
        if i % 10 == 0:
            # Add epoch to epoch_values
            epoch_values.append(i)
            # Generate accuracy stats on test data
            train_accuracy, newCost = sess.run([accuracy_OP, cost_OP], feed_dict={X: trainX, yGold: trainY})
            # Add accuracy to live graphing variable
            accuracy_values.append(train_accuracy)
            # Add cost to live graphing variable
            cost_values.append(newCost)
            # Re-assign values for variables
            diff = abs(newCost - cost)
            cost = newCost
            
            # Generate print statements
            print("step %d, training accuracy %g, cost %g, change in cost %g"%(i, train_accuracy, newCost, diff))
            
# How well do we perform on held-out test data?
print("final accuracy on test set: %s" %str(sess.run(accuracy_OP,
                                                    feed_dict={X: testX,
                                                              yGold: testY})))
# Out:
# step 0, training accuracy 0.333333, cost 33.9271, change in cost 33.9271
# step 10, training accuracy 0.616162, cost 29.835, change in cost 4.09208
# step 20, training accuracy 0.646465, cost 27.9393, change in cost 1.89572
# step 30, training accuracy 0.646465, cost 26.3416, change in cost 1.59773
# step 40, training accuracy 0.646465, cost 25.0137, change in cost 1.3279
# step 50, training accuracy 0.646465, cost 23.9152, change in cost 1.0985
# step 60, training accuracy 0.646465, cost 23.0042, change in cost 0.91095
# step 70, training accuracy 0.646465, cost 22.2438, change in cost 0.760445
# step 80, training accuracy 0.646465, cost 21.6034, change in cost 0.640417
# step 90, training accuracy 0.646465, cost 21.0587, change in cost 0.544628
# step 100, training accuracy 0.666667, cost 20.5909, change in cost 0.4678
# step 110, training accuracy 0.666667, cost 20.1852, change in cost 0.405735
# step 120, training accuracy 0.666667, cost 19.83, change in cost 0.355185
# step 130, training accuracy 0.666667, cost 19.5164, change in cost 0.313656
# step 140, training accuracy 0.666667, cost 19.2371, change in cost 0.279249
# step 150, training accuracy 0.666667, cost 18.9866, change in cost 0.250504
# step 160, training accuracy 0.686869, cost 18.7603, change in cost 0.22628
# step 170, training accuracy 0.686869, cost 18.5546, change in cost 0.205721
# step 180, training accuracy 0.69697, cost 18.3665, change in cost 0.188139
# step 190, training accuracy 0.707071, cost 18.1935, change in cost 0.173002
# step 200, training accuracy 0.717172, cost 18.0336, change in cost 0.15988
# step 210, training accuracy 0.737374, cost 17.8852, change in cost 0.148436
# step 220, training accuracy 0.737374, cost 17.7468, change in cost 0.138399
# step 230, training accuracy 0.747475, cost 17.6172, change in cost 0.129549
# step 240, training accuracy 0.757576, cost 17.4955, change in cost 0.121696
# step 250, training accuracy 0.777778, cost 17.3808, change in cost 0.114704
# step 260, training accuracy 0.787879, cost 17.2724, change in cost 0.108448
# step 270, training accuracy 0.787879, cost 17.1695, change in cost 0.102821
# step 280, training accuracy 0.787879, cost 17.0718, change in cost 0.0977383
# step 290, training accuracy 0.787879, cost 16.9787, change in cost 0.0931358
# step 300, training accuracy 0.79798, cost 16.8897, change in cost 0.0889492
# step 310, training accuracy 0.79798, cost 16.8046, change in cost 0.0851269
# step 320, training accuracy 0.79798, cost 16.723, change in cost 0.081625
# step 330, training accuracy 0.79798, cost 16.6446, change in cost 0.0783997
# step 340, training accuracy 0.808081, cost 16.5691, change in cost 0.0754414
# step 350, training accuracy 0.828283, cost 16.4964, change in cost 0.0726948
# step 360, training accuracy 0.828283, cost 16.4263, change in cost 0.0701504
# step 370, training accuracy 0.838384, cost 16.3585, change in cost 0.0677891
# step 380, training accuracy 0.838384, cost 16.2929, change in cost 0.0655899
# step 390, training accuracy 0.848485, cost 16.2294, change in cost 0.0635281
# step 400, training accuracy 0.848485, cost 16.1678, change in cost 0.0616074
# step 410, training accuracy 0.848485, cost 16.108, change in cost 0.0597973
# step 420, training accuracy 0.848485, cost 16.0499, change in cost 0.0581017
# step 430, training accuracy 0.848485, cost 15.9934, change in cost 0.0565033
# step 440, training accuracy 0.868687, cost 15.9384, change in cost 0.0549946
# step 450, training accuracy 0.868687, cost 15.8848, change in cost 0.053565
# step 460, training accuracy 0.878788, cost 15.8326, change in cost 0.0522146
# step 470, training accuracy 0.878788, cost 15.7817, change in cost 0.0509338
# step 480, training accuracy 0.878788, cost 15.7319, change in cost 0.0497141
# step 490, training accuracy 0.878788, cost 15.6834, change in cost 0.0485563
# step 500, training accuracy 0.878788, cost 15.6359, change in cost 0.047452
# step 510, training accuracy 0.878788, cost 15.5895, change in cost 0.0463963
# step 520, training accuracy 0.878788, cost 15.5441, change in cost 0.045393
# step 530, training accuracy 0.888889, cost 15.4997, change in cost 0.0444298
# step 540, training accuracy 0.89899, cost 15.4562, change in cost 0.0435057
# step 550, training accuracy 0.89899, cost 15.4136, change in cost 0.0426245
# step 560, training accuracy 0.89899, cost 15.3718, change in cost 0.0417738
# step 570, training accuracy 0.89899, cost 15.3309, change in cost 0.0409603
# step 580, training accuracy 0.89899, cost 15.2907, change in cost 0.0401764
# step 590, training accuracy 0.909091, cost 15.2513, change in cost 0.0394182
# step 600, training accuracy 0.909091, cost 15.2126, change in cost 0.0386963
# step 610, training accuracy 0.909091, cost 15.1746, change in cost 0.0379934
# step 620, training accuracy 0.909091, cost 15.1373, change in cost 0.0373163
# step 630, training accuracy 0.909091, cost 15.1006, change in cost 0.0366631
# step 640, training accuracy 0.909091, cost 15.0646, change in cost 0.0360336
# step 650, training accuracy 0.909091, cost 15.0291, change in cost 0.0354195
# step 660, training accuracy 0.909091, cost 14.9943, change in cost 0.0348282
# step 670, training accuracy 0.909091, cost 14.9601, change in cost 0.0342569
# step 680, training accuracy 0.909091, cost 14.9263, change in cost 0.0337019
# step 690, training accuracy 0.909091, cost 14.8932, change in cost 0.0331621
# final accuracy on test set: 0.9

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.plot([np.mean(cost_values[i-50:i]) for i in range(len(cost_values))])
plt.show()
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jupyterlab/conda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
